# %%
import pandas

df = pandas.read_sql_table("telemetry", "sqlite:///nts.db")

print(df)

df2 = df.groupby(["sort", "n", "ordering"], as_index=False).mean()
print(df2)
# Out:
#         id  sort      n    ordering  runtime  memory
# 0        1     1  10000  randomized      NaN     NaN
# 1        2     1  10000      sorted      0.0     0.0
# 2        3     1   1000  randomized      NaN     NaN
# 3        4     1   1000      sorted      0.0     0.0
# 4        5     1    100  randomized      NaN     NaN
# ...    ...   ...    ...         ...      ...     ...
# 1675  1676    12   7500      sorted    150.0   176.0
# 1676  1677    12    750  randomized      0.0    12.0
# 1677  1678    12    750      sorted      1.0    18.0
# 1678  1679    12      8  randomized      0.0     0.0
# 1679  1680    12      8      sorted      0.0     0.0
#
# [1680 rows x 6 columns]
#      sort      n    ordering      id  runtime  memory
# 0       1      8  randomized    83.0      4.2     0.0
# 1       1      8      sorted    84.0      0.0     0.0
# 2       1     10  randomized    63.0     26.0     0.0
# 3       1     10      sorted    64.0      0.0     0.0
# ...

# %%
import plotly.express as px

px.line(df2, "n", "runtime", "sort")

# %%
px.line(df, "n", "memory", "sort")
